# %%
import pandas as pd
import numpy as np
import cv2 as cv

# %%
##assumes dataset in folder
wines   = pd.read_csv("XWines_Full_100K_wines.csv", low_memory=False, encoding="utf-8", memory_map=True)
ratings_df = pd.read_csv("XWines_Slim_150K_ratings.csv", low_memory=False, encoding="utf-8", memory_map=True)
len(wines), len(ratings_df)

print(ratings_df)
print(wines)
# Out:
#         RatingID   UserID  WineID Vintage  Rating                 Date
# 0            143  1356810  103471    1950     4.5  2021-11-02 20:52:59
# 1            199  1173759  111415    1951     5.0  2015-08-20 17:46:26
# 2            348  1164877  111395    1952     5.0  2020-11-13 05:40:26
# 3            374  1207665  111433    1953     5.0  2017-05-05 06:44:13
# 4            834  1075841  111431    1955     5.0  2016-09-14 20:18:38
# ...          ...      ...     ...     ...     ...                  ...
# 149995  21013438  1000052  111468    N.V.     4.5  2021-12-22 21:03:51
# 149996  21013467  1180844  111461    N.V.     4.0  2017-04-23 21:07:55
# 149997  21013494  1218581  113690    N.V.     3.5  2019-04-14 17:45:08
# 149998  21013505  1106198  111468    N.V.     4.5  2021-07-10 07:00:15
# 149999  21013509  1059173  111479    N.V.     5.0  2019-09-08 15:42:28
#
# [150000 rows x 6 columns]
#         WineID                           WineName       Type  \
# 0       100001                 Espumante Moscatel  Sparkling
# 1       100002                         Ancellotta        Red
# 2       100003                 Cabernet Sauvignon        Red
# 3       100004                     Virtus Moscato      White
# 4       100005    Maison de Ville Cabernet-Merlot        Red
# ...        ...                                ...        ...
# 100641  200791      Rulandské Šedé Výběr z Hroznů      White
# 100642  200792  Top Collection Merlot Pozdní Sběr    Dessert
# 100643  200793      Falter Ego Gelber Muskateller      White
# 100644  200794                  Reisberg Riesling      White
# 100645  200795                          Rotleiten        Red
#
#                             Elaborate  \
# 0                       Varietal/100%
# 1                       Varietal/100%
# 2                       Varietal/100%
# 3                       Varietal/100%
# 4       Assemblage/Bordeaux Red Blend
# ...                               ...
# 100641                  Varietal/100%
# 100642                  Varietal/100%
# 100643                  Varietal/100%
# 100644                  Varietal/100%
# 100645               Assemblage/Blend
#
#                                                    Grapes  \
# 0                                      ['Muscat/Moscato']
# 1                                          ['Ancellotta']
# 2                                  ['Cabernet Sauvignon']
# 3                                      ['Muscat/Moscato']
# 4                        ['Cabernet Sauvignon', 'Merlot']
# ...                                                   ...
# 100641                                     ['Pinot Gris']
# 100642                                         ['Merlot']
# 100643                             ['Gelber Muskateller']
# 100644                                       ['Riesling']
# 100645  ['Cabernet Sauvignon', 'Zweigelt', 'St. Laurent']
#
#                                                 Harmonize   ABV  \
# 0                      ['Pork', 'Rich Fish', 'Shellfish']   7.5
# 1       ['Beef', 'Barbecue', 'Codfish', 'Pasta', 'Pizz...  12.0
# 2                             ['Beef', 'Lamb', 'Poultry']  12.0
# 3                                       ['Sweet Dessert']  12.0
# 4                ['Beef', 'Lamb', 'Game Meat', 'Poultry']  11.0
# ...                                                   ...   ...
# 100641  ['Rich Fish', 'Shellfish', 'Maturated Cheese',...  13.0
# 100642                              ['Beef', 'Game Meat']  13.5
# 100643                    ['Spicy Food', 'Sweet Dessert']  12.5
# 100644  ['Pork', 'Shellfish', 'Spicy Food', 'Poultry',...  12.5
# 100645  ['Beef', 'Lamb', 'Pork', 'Spicy Food', 'Matura...  13.5
#
#                  Body Acidity Code         Country  RegionID     RegionName  \
# 0       Medium-bodied    High   BR          Brazil      1001   Serra Gaúcha
# 1       Medium-bodied  Medium   BR          Brazil      1001   Serra Gaúcha
# 2         Full-bodied    High   BR          Brazil      1001   Serra Gaúcha
# 3       Medium-bodied  Medium   BR          Brazil      1001   Serra Gaúcha
# 4         Full-bodied  Medium   BR          Brazil      1001   Serra Gaúcha
# ...               ...     ...  ...             ...       ...            ...
# 100641  Medium-bodied  Medium   CZ  Czech Republic      2295         Morava
# 100642  Medium-bodied    High   CZ  Czech Republic      2295         Morava
# 100643  Medium-bodied    High   AT         Austria      2086  Südsteiermark
# 100644  Medium-bodied    High   AT         Austria      2093           Wien
# 100645  Medium-bodied    High   AT         Austria      2093           Wien
#
#         WineryID                      WineryName  \
# 0          10001                     Casa Perini
# 1          10001                     Casa Perini
# 2          10002                    Castellamare
# 3          10003                  Monte Paschoal
# 4          10000                          Aurora
# ...          ...                             ...
# 100641     67056  Rodinné Vinařství Pavel Binder
# 100642     66978              Vinarstvi Mutěnice
# 100643     62547                  Hannes Sabathi
# 100644     62795                           Zahel
# 100645     62795                           Zahel
#
#                                        Website  \
# 0             http://www.vinicolaperini.com.br
# 1             http://www.vinicolaperini.com.br
# 2       https://www.emporiocastellamare.com.br
# 3              http://www.montepaschoal.com.br
# 4             http://www.vinicolaaurora.com.br
# ...                                        ...
# 100641               http://www.pavelbinder.cz
# 100642         http://www.vinarstvimutenice.cz
# 100643             http://www.sabathi-weine.at
# 100644                     http://www.zahel.at
# 100645                     http://www.zahel.at
#
#                                                  Vintages
# 0       [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 1       [2016, 2015, 2014, 2013, 2012, 2011, 2010, 200...
# 2       [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 3       [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 4       [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# ...                                                   ...
# 100641  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...
# 100642   [2020, 2019, 2018, 2017, 2016, 2015, 2013, 2010]
# 100643  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 100644  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 100645  [2020, 2019, 2017, 2015, 2014, 2013, 2012, 201...
#
# [100646 rows x 17 columns]

# %%
import config as cfg

group_sizes_to_create = cfg.group_sizes_to_create
group_similarity_to_create = cfg.group_similarity_to_create
group_number = cfg.group_number

print(group_number)
# Out:
# 20

# %%
import pandas as pd

display(ratings_df.head(10))
# Out:
#    RatingID   UserID  WineID Vintage  Rating                 Date
# 0       143  1356810  103471    1950     4.5  2021-11-02 20:52:59
# 1       199  1173759  111415    1951     5.0  2015-08-20 17:46:26
# 2       348  1164877  111395    1952     5.0  2020-11-13 05:40:26
# 3       374  1207665  111433    1953     5.0  2017-05-05 06:44:13
# 4       834  1075841  111431    1955     5.0  2016-09-14 20:18:38
# 5       876  1211463  111395    1955     5.0  2021-12-02 23:12:49
# 6      1005  1076348  111433    1955     4.5  2021-06-19 19:53:56
# 7      1020  1147051  111429    1955     5.0  2018-07-08 20:09:46
# 8      1029  1225931  111431    1955     5.0  2017-04-24 01:41:52
# 9      1399  1197513  111415    1958     5.0  2014-07-04 01:07:16

# %% [markdown]
# # Similarity evaluation
#
# Evaluation of the similarity between all the pairs o users in the dataset.

# %%
# Counts the amount of ratings per user
ratings_per_user = ratings_df.groupby('UserID').size()

# Calculate the average number of ratings per user
average_number_of_rating = ratings_per_user.mean()

#Round Value
rounded_average_number_of_rating = round(average_number_of_rating)
print(rounded_average_number_of_rating)
# Out:
# 14

# %%
# Count the number of ratings for each user
user_counts = ratings_df['UserID'].value_counts()

# Filter users who have at least the specified number of ratings
filtered_users = user_counts[user_counts <= rounded_average_number_of_rating].index

# Filter the DataFrame to keep only these users
ratings_df = ratings_df[ratings_df['UserID'].isin(filtered_users)]
print(ratings_df)
# Out:
#         RatingID   UserID  WineID Vintage  Rating                 Date
# 3            374  1207665  111433    1953     5.0  2017-05-05 06:44:13
# 4            834  1075841  111431    1955     5.0  2016-09-14 20:18:38
# 5            876  1211463  111395    1955     5.0  2021-12-02 23:12:49
# 6           1005  1076348  111433    1955     4.5  2021-06-19 19:53:56
# 8           1029  1225931  111431    1955     5.0  2017-04-24 01:41:52
# ...          ...      ...     ...     ...     ...                  ...
# 149993  21013409  1086949  111484    N.V.     4.5  2019-04-14 17:31:49
# 149994  21013430  1026866  111479    N.V.     4.0  2014-11-22 15:00:48
# 149995  21013438  1000052  111468    N.V.     4.5  2021-12-22 21:03:51
# 149997  21013494  1218581  113690    N.V.     3.5  2019-04-14 17:45:08
# 149999  21013509  1059173  111479    N.V.     5.0  2019-09-08 15:42:28
#
# [70480 rows x 6 columns]

# %%
# computing similarity between each pair of users

import numpy as np

user_matrix = ratings_df.pivot_table(columns='WineID', index='UserID', values='Rating')

user_id_set = set(ratings_df['UserID'])
user_id_indexes = user_matrix.index.values
user_matrix = user_matrix.fillna(0)
numpy_array = user_matrix.to_numpy()
sim_matrix = np.corrcoef(numpy_array)

display(sim_matrix)
# display(list(user_id_indexes))
# display(user_id_set)
# Out:
# array([[ 1.        ,  0.06229714,  0.10011552, ..., -0.00336172,
#          0.05536035, -0.0126063 ],
#        [ 0.06229714,  1.        , -0.01023966, ..., -0.00323121,
#         -0.01169489, -0.01211689],
#        [ 0.10011552, -0.01023966,  1.        , ..., -0.00323037,
#         -0.01169185, -0.01211373],
#        ...,
#        [-0.00336172, -0.00323121, -0.00323037, ...,  1.        ,
#         -0.00368946, -0.00382259],
#        [ 0.05536035, -0.01169489, -0.01169185, ..., -0.00368946,
#          1.        , -0.0138353 ],
#        [-0.0126063 , -0.01211689, -0.01211373, ..., -0.00382259,
#         -0.0138353 ,  1.        ]])

# %% [markdown]
# ## Visualization of the similarity distribution

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(sim_matrix.flatten())
plt.yscale("log")
plt.xlabel("Pearson's Correlation Coeficient")
# Out:
# Text(0.5, 0, "Pearson's Correlation Coeficient")

# %%
from groups_generators import GroupsGenerator
user_id_set = sorted(user_id_set)
group_list = list()
for group_type in group_similarity_to_create:
    print(group_type)
    grpGenerator = GroupsGenerator.getGroupsGenerator(group_type)
    current_list = grpGenerator.generateGroups(user_id_indexes, user_id_set, sim_matrix, group_sizes_to_create, group_number)
    
    display(pd.DataFrame.from_records(current_list))
    
    group_list = group_list + current_list
# Out:
# RANDOM
# 20
# 40
# 60
#     group_size group_similarity  \
# 0            2           random
# 1            2           random
# 2            2           random
# 3            2           random
# 4            2           random
# 5            2           random
# 6            2           random
# 7            2           random
# 8            2           random
# 9            2           random
# 10           2           random
# 11           2           random
# 12           2           random
# 13           2           random
# 14           2           random
# 15           2           random
# 16           2           random
# 17           2           random
# 18           2           random
# 19           2           random
# 20           4           random
# 21           4           random
# 22           4           random
# 23           4           random
# 24           4           random
# 25           4           random
# 26           4           random
# 27           4           random
# 28           4           random
# 29           4           random
# 30           4           random
# 31           4           random
# 32           4           random
# 33           4           random
# 34           4           random
# 35           4           random
# 36           4           random
# 37           4           random
# 38           4           random
# 39           4           random
# 40           8           random
# 41           8           random
# 42           8           random
# 43           8           random
# 44           8           random
# 45           8           random
# 46           8           random
# 47           8           random
# 48           8           random
# 49           8           random
# 50           8           random
# 51           8           random
# 52           8           random
# 53           8           random
# 54           8           random
# 55           8           random
# 56           8           random
# 57           8           random
# 58           8           random
# 59           8           random
#
#                                         group_members  avg_similarity
# 0                                  [1289797, 1393700]       -0.009674
# 1                                  [1366127, 1004168]       -0.008242
# 2                                  [1240789, 1277541]       -0.010677
# 3                                  [1689752, 1155516]        0.079470
# 4                                  [1402831, 1135188]       -0.010666
# 5                                  [1019546, 1216671]        0.084150
# 6                                  [1250221, 1364007]       -0.011004
# 7                                  [2049904, 1298350]       -0.008542
# 8                                  [1009530, 1457483]        0.173955
# 9                                  [1004382, 1275951]       -0.009082
# 10                                 [1221398, 1164014]       -0.008892
# 11                                 [1040963, 1178347]       -0.013024
# 12                                 [1631797, 1012007]        0.152034
# 13                                 [1244405, 1231172]        0.072860
# 14                                 [1228279, 1005903]        0.123389
# 15                                 [1096633, 1241148]        0.076466
# 16                                 [1043811, 1287061]       -0.009188
# 17                                 [1858010, 1022648]       -0.011143
# 18                                 [1218475, 1005729]       -0.010041
# 19                                 [1014196, 1087758]       -0.003216
# 20               [1284075, 1596061, 1185282, 1221595]        0.088439
# 21               [1215056, 1740088, 1281028, 1235741]        0.028160
# 22               [1264967, 1174834, 1176873, 1037083]       -0.007431
# 23               [1113521, 1553202, 1388324, 1252972]        0.008423
# 24               [1212179, 1034226, 1013029, 1114047]        0.051725
# 25               [2047857, 1218275, 1230668, 1663206]        0.002911
# 26               [1236177, 1450430, 1212097, 1984572]        0.041643
# 27               [1139703, 1313170, 1763922, 1164315]        0.053280
# 28               [1290504, 1129715, 1183143, 1137692]        0.051383
# 29               [1067120, 1196595, 1455207, 1219321]        0.053646
# 30               [1666232, 1389759, 1270861, 1104249]        0.058262
# 31               [1267547, 1357595, 1167065, 1725090]        0.000198
# 32               [1249468, 1280918, 1202920, 1708201]        0.025804
# 33               [1986536, 1777497, 1115976, 1187707]        0.067186
# 34               [1387564, 1275123, 1056552, 1765977]        0.018657
# 35               [1230852, 1042265, 1232253, 1149217]        0.009242
# 36               [1234135, 1002052, 1141906, 1621968]        0.019658
# 37               [1263186, 1273492, 1360661, 1396569]        0.021705
# 38               [1176000, 1183896, 1182750, 1288838]        0.044016
# 39               [1204645, 1538636, 1079535, 1630026]        0.021389
# 40  [1174111, 1245188, 1218454, 1223320, 1112055, ...        0.022144
# 41  [1079318, 1464722, 1403679, 1030837, 1480508, ...        0.026261
# 42  [1016719, 1213725, 1048667, 1190263, 1608531, ...        0.041785
# 43  [1300803, 1186144, 1360735, 1079318, 1245040, ...        0.006101
# 44  [1004761, 1004847, 1898824, 1324684, 1201081, ...        0.009896
# 45  [1221777, 1997772, 1012989, 1266445, 1252653, ...        0.020586
# 46  [1000067, 1196203, 1235925, 1264364, 1647660, ...        0.040636
# 47  [1284349, 1146933, 1003977, 1163123, 1400386, ...        0.012746
# 48  [1005914, 1474440, 1985825, 1112457, 1243955, ...        0.033192
# 49  [1876255, 1139690, 1300959, 1001940, 1916989, ...        0.014934
# 50  [1236934, 1197255, 1034976, 1285623, 1920071, ...        0.015323
# 51  [1194991, 1236213, 1269304, 1228136, 1123914, ...        0.005798
# 52  [1859448, 1280803, 1550673, 1055003, 1225379, ...        0.021995
# 53  [1013614, 1137580, 1144715, 1396059, 1505103, ...        0.015599
# 54  [1284557, 1207111, 1604011, 1903679, 1222163, ...        0.021972
# 55  [1947000, 1409246, 1502969, 1114543, 1075898, ...        0.032643
# 56  [1325598, 1226481, 1004485, 1605366, 1043509, ...        0.031468
# 57  [1764158, 1143566, 1066882, 1255451, 1217261, ...        0.051921
# 58  [1404105, 1295603, 1254172, 1167635, 1361588, ...        0.018164
# 59  [1694373, 1006514, 1213854, 1216155, 1865286, ...        0.027556
# SIMILAR
# 20
# 40
# 60
#     group_size group_similarity  \
# 0            2          similar
# 1            2          similar
# 2            2          similar
# 3            2          similar
# 4            2          similar
# 5            2          similar
# 6            2          similar
# 7            2          similar
# 8            2          similar
# 9            2          similar
# 10           2          similar
# 11           2          similar
# 12           2          similar
# 13           2          similar
# 14           2          similar
# 15           2          similar
# 16           2          similar
# 17           2          similar
# 18           2          similar
# 19           2          similar
# 20           4          similar
# 21           4          similar
# 22           4          similar
# 23           4          similar
# 24           4          similar
# 25           4          similar
# 26           4          similar
# 27           4          similar
# 28           4          similar
# 29           4          similar
# 30           4          similar
# 31           4          similar
# 32           4          similar
# 33           4          similar
# 34           4          similar
# 35           4          similar
# 36           4          similar
# 37           4          similar
# 38           4          similar
# 39           4          similar
# 40           8          similar
# 41           8          similar
# 42           8          similar
# 43           8          similar
# 44           8          similar
# 45           8          similar
# 46           8          similar
# 47           8          similar
# 48           8          similar
# 49           8          similar
# 50           8          similar
# 51           8          similar
# 52           8          similar
# 53           8          similar
# 54           8          similar
# 55           8          similar
# 56           8          similar
# 57           8          similar
# 58           8          similar
# 59           8          similar
#
#                                         group_members  avg_similarity
# 0                                  [1217008, 1194434]        0.549566
# 1                                  [1212329, 1207902]        0.506479
# 2                                  [1846560, 1604375]        0.630797
# 3                                  [1263844, 1165263]        0.588674
# 4                                  [1451130, 1039599]        0.501760
# 5                                  [1157170, 1129796]        0.572659
# 6                                  [1078947, 1686051]        0.544228
# 7                                  [1181392, 1185705]        0.561046
# 8                                  [1055246, 1126696]        0.558778
# 9                                  [1255882, 1134441]        0.548997
# 10                                 [1387930, 1936578]        1.000000
# 11                                 [1213854, 1198871]        0.688204
# 12                                 [1180363, 1157714]        0.579354
# 13                                 [1356607, 1236738]        0.505696
# 14                                 [1121498, 1060499]        0.558508
# 15                                 [1184762, 1144911]        0.502027
# 16                                 [1130804, 1979847]        1.000000
# 17                                 [1196681, 1356631]        1.000000
# 18                                 [1183876, 1209317]        1.000000
# 19                                 [1065010, 1775941]        0.521293
# 20               [1666823, 1430963, 1030557, 2017960]        1.000000
# 21               [1183143, 1206063, 1912073, 1262657]        0.487180
# 22               [1240219, 1893257, 1062080, 1193044]        0.568061
# 23               [1006466, 1389471, 1165895, 1213809]        0.448295
# 24               [1255156, 1006724, 1681975, 1867074]        1.000000
# 25               [1211855, 1209664, 1103172, 1076345]        0.430184
# 26               [1010311, 1061532, 1466478, 1832353]        0.448987
# 27               [1360053, 1224295, 1221399, 1018523]        0.455299
# 28               [1278745, 1221399, 1224295, 1360053]        0.457342
# 29               [1265629, 1224855, 1072986, 1226880]        0.429428
# 30               [1052127, 1144715, 1205159, 1067750]        0.459608
# 31               [1232581, 1255091, 1120866, 1254398]        0.450763
# 32               [1365765, 1034827, 1103774, 1054242]        0.489339
# 33               [1142742, 1002695, 1084123, 1078943]        0.508303
# 34               [1283660, 1951881, 1141413, 1142409]        0.546867
# 35               [1284102, 1126410, 1223913, 1059230]        0.471711
# 36               [1028961, 2032505, 1329637, 1095426]        1.000000
# 37               [1042239, 1213735, 1204723, 1205921]        0.683271
# 38               [1099317, 1205921, 1207569, 1084406]        0.478453
# 39               [1170383, 2042208, 1034827, 1140417]        0.396581
# 40  [1200315, 1208054, 1209326, 1060499, 1215905, ...        0.359266
# 41  [1269883, 1903608, 1055458, 1208171, 1797823, ...        0.452457
# 42  [1177814, 1186270, 1100667, 1406732, 1951019, ...        0.339880
# 43  [1048496, 1065607, 1000513, 1034534, 1037083, ...        0.389742
# 44  [1799506, 1286865, 2024608, 1020486, 1207521, ...        0.363840
# 45  [1122134, 1282569, 1287978, 1287038, 1820305, ...        0.391544
# 46  [1136602, 1495734, 1226084, 1228140, 1208287, ...        0.361243
# 47  [1142271, 1644588, 1104909, 1110028, 1083893, ...        0.365736
# 48  [1287038, 1037746, 1944469, 1078625, 1046448, ...        0.525358
# 49  [1909490, 1324444, 1123444, 1270325, 1451130, ...        0.351092
# 50  [1393119, 1294080, 1340606, 1149986, 1166271, ...        0.454952
# 51  [1410998, 1216464, 1154133, 1119676, 1294331, ...        0.389283
# 52  [1236738, 1356607, 1282569, 1227953, 1066078, ...        0.374322
# 53  [1592043, 1278001, 1021833, 1045782, 1269791, ...        0.356581
# 54  [1179130, 1124065, 1216268, 1214227, 1718475, ...        0.436962
# 55  [1041633, 1049388, 1097526, 1851305, 1290507, ...        0.285050
# 56  [1022794, 1218536, 1167211, 1041516, 1202060, ...        0.358997
# 57  [1216925, 1205584, 1205085, 1089523, 1389759, ...        0.385596
# 58  [1165896, 1253739, 1201812, 1217196, 1196804, ...        0.419581
# 59  [1902473, 1258142, 1356669, 1858895, 1120912, ...        0.319944
# DIVERGENT
# 20
# 40
# 60
#     group_size group_similarity  \
# 0            2        divergent
# 1            2        divergent
# 2            2        divergent
# 3            2        divergent
# 4            2        divergent
# 5            2        divergent
# 6            2        divergent
# 7            2        divergent
# 8            2        divergent
# 9            2        divergent
# 10           2        divergent
# 11           2        divergent
# 12           2        divergent
# 13           2        divergent
# 14           2        divergent
# 15           2        divergent
# 16           2        divergent
# 17           2        divergent
# 18           2        divergent
# 19           2        divergent
# 20           4        divergent
# 21           4        divergent
# 22           4        divergent
# 23           4        divergent
# 24           4        divergent
# 25           4        divergent
# 26           4        divergent
# 27           4        divergent
# 28           4        divergent
# 29           4        divergent
# 30           4        divergent
# 31           4        divergent
# 32           4        divergent
# 33           4        divergent
# 34           4        divergent
# 35           4        divergent
# 36           4        divergent
# 37           4        divergent
# 38           4        divergent
# 39           4        divergent
# 40           8        divergent
# 41           8        divergent
# 42           8        divergent
# 43           8        divergent
# 44           8        divergent
# 45           8        divergent
# 46           8        divergent
# 47           8        divergent
# 48           8        divergent
# 49           8        divergent
# 50           8        divergent
# 51           8        divergent
# 52           8        divergent
# 53           8        divergent
# 54           8        divergent
# 55           8        divergent
# 56           8        divergent
# 57           8        divergent
# 58           8        divergent
# 59           8        divergent
#
#                                         group_members  avg_similarity
# 0                                  [1001115, 1043126]       -0.009946
# 1                                  [1393931, 1251932]       -0.011352
# 2                                  [1359948, 1269564]        0.082522
# 3                                  [1262677, 1126696]       -0.008889
# 4                                  [1304533, 1944444]       -0.003238
# 5                                  [1040928, 1224146]       -0.010549
# 6                                  [1413139, 1120931]       -0.009139
# 7                                  [1404105, 1004362]       -0.011014
# 8                                  [1489449, 1098947]       -0.012202
# 9                                  [1139365, 1511164]       -0.010520
# 10                                 [1322183, 1265895]       -0.013576
# 11                                 [1235408, 1181392]       -0.010046
# 12                                 [1107874, 1230191]       -0.011100
# 13                                 [1266755, 1210217]       -0.006410
# 14                                 [1152390, 1100074]        0.058442
# 15                                 [1223473, 1040098]       -0.011121
# 16                                 [1071118, 1044048]       -0.007575
# 17                                 [1205533, 1041042]       -0.005001
# 18                                 [1226760, 1950031]        0.078555
# 19                                 [1324444, 1003712]       -0.012377
# 20               [1192021, 1253065, 1246161, 1394317]        0.012493
# 21               [1129789, 1188744, 1840307, 1399242]        0.038921
# 22               [1049843, 1043141, 1141920, 1083794]        0.009249
# 23               [1281621, 1469764, 1649493, 1104491]        0.042144
# 24               [1212059, 1387436, 1044421, 1000582]       -0.009568
# 25               [1218634, 1281588, 1387930, 1218194]        0.022431
# 26               [1537657, 1763922, 1820305, 1708783]        0.015846
# 27               [1093422, 1059736, 1509439, 1274530]       -0.004387
# 28               [1154996, 1213524, 1198558, 1222691]        0.035002
# 29               [1249047, 1164133, 1268161, 2012543]       -0.006660
# 30               [1120794, 1254398, 1216671, 1186038]        0.025603
# 31               [1178254, 1300715, 1274444, 1229652]        0.020462
# 32               [1064848, 1169832, 1222895, 1125303]       -0.007059
# 33               [1055122, 1049428, 1137655, 1253065]        0.061347
# 34               [1006666, 1165937, 1456577, 1221534]        0.017318
# 35               [1304533, 1218536, 1035531, 1219324]       -0.009061
# 36               [1979847, 1166139, 1094363, 1166064]        0.028733
# 37               [1189581, 1223159, 1278825, 1279089]        0.097664
# 38               [1026306, 1204097, 1320442, 1115688]        0.030064
# 39               [1088889, 1362729, 1059725, 1222163]       -0.011541
# 40  [1174718, 1007198, 1290767, 1175938, 1269552, ...        0.046123
# 41  [1255093, 1266755, 1027693, 1980435, 1266408, ...        0.010384
# 42  [1203928, 1308156, 1467023, 1283309, 1934191, ...        0.032154
# 43  [1230191, 1112534, 1243721, 1284349, 1026697, ...        0.038935
# 44  [1098103, 1075700, 1134778, 1215124, 1041030, ...        0.053116
# 45  [1006408, 1357341, 1004849, 1164188, 1378501, ...        0.033156
# 46  [1185024, 1220947, 1166946, 1283446, 1255667, ...        0.018371
# 47  [1274690, 1059785, 1361080, 1165047, 1117674, ...        0.040418
# 48  [1842106, 1165070, 2056340, 1762859, 1144708, ...        0.007943
# 49  [1253724, 1093422, 1240482, 1048332, 1753301, ...        0.027869
# 50  [1664142, 1035728, 1236079, 1270683, 1272667, ...        0.024868
# 51  [1014359, 1131509, 1003957, 1265381, 1220980, ...        0.028002
# 52  [1083598, 1008267, 1277139, 1207521, 1253019, ...        0.037346
# 53  [1284149, 1059095, 1398559, 1197373, 1300715, ...        0.007082
# 54  [1215762, 1064790, 1972850, 1320442, 1363431, ...        0.004738
# 55  [1271502, 1258142, 1248297, 1387930, 1387702, ...        0.013250
# 56  [1038969, 1189783, 1270653, 1004867, 1199402, ...        0.012562
# 57  [1114191, 1219577, 1218911, 1132373, 1835557, ...        0.049452
# 58  [1396561, 1358604, 1282368, 1223590, 1150753, ...        0.068704
# 59  [1372222, 1160009, 1151162, 1000197, 1592605, ...        0.051685
# SIMILAR_ONE_DIVERGENT
# 20
# 40
# 60
#     group_size       group_similarity  \
# 0            2  similar_one_divergent
# 1            2  similar_one_divergent
# 2            2  similar_one_divergent
# 3            2  similar_one_divergent
# 4            2  similar_one_divergent
# 5            2  similar_one_divergent
# 6            2  similar_one_divergent
# 7            2  similar_one_divergent
# 8            2  similar_one_divergent
# 9            2  similar_one_divergent
# 10           2  similar_one_divergent
# 11           2  similar_one_divergent
# 12           2  similar_one_divergent
# 13           2  similar_one_divergent
# 14           2  similar_one_divergent
# 15           2  similar_one_divergent
# 16           2  similar_one_divergent
# 17           2  similar_one_divergent
# 18           2  similar_one_divergent
# 19           2  similar_one_divergent
# 20           4  similar_one_divergent
# 21           4  similar_one_divergent
# 22           4  similar_one_divergent
# 23           4  similar_one_divergent
# 24           4  similar_one_divergent
# 25           4  similar_one_divergent
# 26           4  similar_one_divergent
# 27           4  similar_one_divergent
# 28           4  similar_one_divergent
# 29           4  similar_one_divergent
# 30           4  similar_one_divergent
# 31           4  similar_one_divergent
# 32           4  similar_one_divergent
# 33           4  similar_one_divergent
# 34           4  similar_one_divergent
# 35           4  similar_one_divergent
# 36           4  similar_one_divergent
# 37           4  similar_one_divergent
# 38           4  similar_one_divergent
# 39           4  similar_one_divergent
# 40           8  similar_one_divergent
# 41           8  similar_one_divergent
# 42           8  similar_one_divergent
# 43           8  similar_one_divergent
# 44           8  similar_one_divergent
# 45           8  similar_one_divergent
# 46           8  similar_one_divergent
# 47           8  similar_one_divergent
# 48           8  similar_one_divergent
# 49           8  similar_one_divergent
# 50           8  similar_one_divergent
# 51           8  similar_one_divergent
# 52           8  similar_one_divergent
# 53           8  similar_one_divergent
# 54           8  similar_one_divergent
# 55           8  similar_one_divergent
# 56           8  similar_one_divergent
# 57           8  similar_one_divergent
# 58           8  similar_one_divergent
# 59           8  similar_one_divergent
#
#                                         group_members  avg_similarity
# 0                                  [1034368, 1222877]       -0.012044
# 1                                  [1429762, 1965776]       -0.005406
# 2                                  [1244965, 1392126]       -0.008695
# 3                                  [1151814, 1254482]       -0.009455
# 4                                  [1036201, 1398559]       -0.003223
# 5                                  [1210613, 1191221]       -0.011151
# 6                                  [1219072, 1335034]       -0.011081
# 7                                  [1114047, 1251633]       -0.010245
# 8                                  [1139787, 1060016]       -0.008504
# 9                                  [1183569, 1121498]       -0.008495
# 10                                 [1787810, 1416040]       -0.009253
# 11                                 [1131099, 1121001]       -0.008846
# 12                                 [1019075, 1272771]        0.096263
# 13                                 [1000232, 1217270]        0.040591
# 14                                 [1329637, 1626693]       -0.003625
# 15                                 [1408900, 1734387]       -0.010509
# 16                                 [1253011, 1893593]       -0.010848
# 17                                 [1094363, 1653207]       -0.010157
# 18                                 [1149098, 1123719]        0.095612
# 19                                 [1213476, 1012457]        0.058085
# 20               [1893593, 1154133, 1037083, 1002512]        0.209001
# 21               [1207793, 1084397, 1041042, 1001115]        0.256143
# 22               [1173699, 1340606, 1185360, 1703926]        0.262329
# 23               [1001006, 1252744, 1645346, 1206310]        0.211354
# 24               [2049904, 1231285, 1037746, 1162954]        0.253736
# 25               [1201456, 1165895, 1389471, 1254857]        0.254475
# 26               [1435074, 1034425, 1341570, 1008899]        0.266617
# 27               [1251932, 1177660, 1075757, 1354019]        0.277691
# 28               [1366008, 1037083, 1121081, 1262028]        0.224061
# 29               [1907099, 1213731, 1494147, 1389297]        0.498324
# 30               [1737753, 1213919, 1119676, 1203304]        0.344563
# 31               [1820577, 1359948, 1282644, 1001045]        0.223549
# 32               [1665540, 1010311, 1673185, 1239680]        0.252106
# 33               [1689187, 1123444, 1103929, 1986488]        0.288471
# 34               [1168394, 1410597, 1218072, 1087977]        0.243520
# 35               [1925634, 2015016, 1400386, 1301428]        0.400504
# 36               [1203304, 1912073, 1065008, 1357701]        0.226045
# 37               [1211855, 1144715, 1099317, 1055788]        0.234092
# 38               [1286607, 1303176, 1271502, 1233025]        0.243848
# 39               [1398559, 1071163, 1674727, 1367431]        0.498229
# 40  [1820577, 1359948, 1282644, 1031118, 1858010, ...        0.311554
# 41  [1124387, 1944469, 1287038, 1207793, 1142409, ...        0.303654
# 42  [1120866, 1254398, 1278001, 1021833, 1055602, ...        0.312424
# 43  [1243410, 1186270, 1086949, 1127231, 1100667, ...        0.348698
# 44  [1076120, 1210920, 1209326, 1294331, 1084761, ...        0.355064
# 45  [1105176, 1223348, 1278805, 1290188, 1944469, ...        0.311461
# 46  [1011730, 1179336, 2056705, 1002695, 1152054, ...        0.358309
# 47  [1930194, 1036414, 1055122, 1191914, 1035442, ...        0.352643
# 48  [1055444, 1239656, 1057231, 1156175, 1124490, ...        0.327112
# 49  [1103272, 1084761, 1797823, 1708704, 1445937, ...        0.286594
# 50  [1137583, 1205533, 1191624, 1258453, 1089025, ...        0.330410
# 51  [1215717, 1211375, 1076431, 1213725, 1210675, ...        0.333414
# 52  [1129715, 1213842, 1294080, 1210483, 1216699, ...        0.318907
# 53  [1223913, 1357341, 1126410, 1269590, 1078625, ...        0.310043
# 54  [1134614, 1775941, 1201081, 1230434, 1055055, ...        0.282729
# 55  [1000197, 1930194, 1055122, 1036414, 1186270, ...        0.284153
# 56  [1041516, 1410998, 2056705, 1116649, 1202471, ...        0.307279
# 57  [1225885, 1291971, 1970683, 1215574, 1199595, ...        0.322501
# 58  [1269791, 2004485, 1071205, 1698639, 1281152, ...        0.314933
# 59  [1099585, 1526469, 1055318, 1406748, 1355947, ...        0.257073

# %%
# group_list = group_list_random + group_list_similar + group_list_divergent + group_list_sim_one_div
#group_list = group_list_sim_one_div

group_dict = dict()
for group_id, group in zip(range(len(group_list)), group_list):
    group_dict[group_id] = group
display(group_dict)
# Out:
# {0: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1289797, 1393700],
#   'avg_similarity': -0.009673893454841018},
#  1: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1366127, 1004168],
#   'avg_similarity': -0.008241751284406532},
#  2: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1240789, 1277541],
#   'avg_similarity': -0.010676955244883476},
#  3: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1689752, 1155516],
#   'avg_similarity': 0.07947019493999614},
#  4: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1402831, 1135188],
#   'avg_similarity': -0.010666239142897119},
#  5: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1019546, 1216671],
#   'avg_similarity': 0.08415046686428257},
#  6: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1250221, 1364007],
#   'avg_similarity': -0.011003824065782724},
#  7: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2049904, 1298350],
#   'avg_similarity': -0.008541624648905097},
#  8: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1009530, 1457483],
#   'avg_similarity': 0.17395466808015783},
#  9: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1004382, 1275951],
#   'avg_similarity': -0.00908231773801612},
#  10: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1221398, 1164014],
#   'avg_similarity': -0.008892405679349166},
#  11: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1040963, 1178347],
#   'avg_similarity': -0.013024156283587943},
#  12: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1631797, 1012007],
#   'avg_similarity': 0.15203432329056132},
#  13: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1244405, 1231172],
#   'avg_similarity': 0.0728595099436054},
#  14: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1228279, 1005903],
#   'avg_similarity': 0.12338936650637837},
#  15: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1096633, 1241148],
#   'avg_similarity': 0.07646648105057897},
#  16: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1043811, 1287061],
#   'avg_similarity': -0.00918752569024748},
#  17: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1858010, 1022648],
#   'avg_similarity': -0.011142820175772613},
#  18: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1218475, 1005729],
#   'avg_similarity': -0.01004139973882109},
#  19: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1014196, 1087758],
#   'avg_similarity': -0.003216448952080255},
#  20: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1284075, 1596061, 1185282, 1221595],
#   'avg_similarity': 0.08843870484071507},
#  21: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1215056, 1740088, 1281028, 1235741],
#   'avg_similarity': 0.028159530301750016},
#  22: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1264967, 1174834, 1176873, 1037083],
#   'avg_similarity': -0.007430671369262701},
#  23: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1113521, 1553202, 1388324, 1252972],
#   'avg_similarity': 0.008423325674438575},
#  24: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1212179, 1034226, 1013029, 1114047],
#   'avg_similarity': 0.05172542550503093},
#  25: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [2047857, 1218275, 1230668, 1663206],
#   'avg_similarity': 0.0029111954242040214},
#  26: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1236177, 1450430, 1212097, 1984572],
#   'avg_similarity': 0.041643016321045945},
#  27: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1139703, 1313170, 1763922, 1164315],
#   'avg_similarity': 0.053279651888312664},
#  28: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1290504, 1129715, 1183143, 1137692],
#   'avg_similarity': 0.05138274322236704},
#  29: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1067120, 1196595, 1455207, 1219321],
#   'avg_similarity': 0.05364554261465274},
#  30: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1666232, 1389759, 1270861, 1104249],
#   'avg_similarity': 0.05826150100165886},
#  31: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1267547, 1357595, 1167065, 1725090],
#   'avg_similarity': 0.0001984922517189481},
#  32: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1249468, 1280918, 1202920, 1708201],
#   'avg_similarity': 0.025803791564862},
#  33: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1986536, 1777497, 1115976, 1187707],
#   'avg_similarity': 0.06718640718634093},
#  34: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1387564, 1275123, 1056552, 1765977],
#   'avg_similarity': 0.018656998733502097},
#  35: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1230852, 1042265, 1232253, 1149217],
#   'avg_similarity': 0.009241567753365395},
#  36: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1234135, 1002052, 1141906, 1621968],
#   'avg_similarity': 0.019658014275274444},
#  37: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1263186, 1273492, 1360661, 1396569],
#   'avg_similarity': 0.021704665765489115},
#  38: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1176000, 1183896, 1182750, 1288838],
#   'avg_similarity': 0.044015610354870505},
#  39: {'group_size': 4,
#   'group_similarity': 'random',
#   'group_members': [1204645, 1538636, 1079535, 1630026],
#   'avg_similarity': 0.0213893488267409},
#  40: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1174111,
#    1245188,
#    1218454,
#    1223320,
#    1112055,
#    1947450,
#    1164315,
#    1002798],
#   'avg_similarity': 0.02214420403518445},
#  41: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1079318,
#    1464722,
#    1403679,
#    1030837,
#    1480508,
#    1360947,
#    1049315,
#    1112213],
#   'avg_similarity': 0.026261451870533088},
#  42: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1016719,
#    1213725,
#    1048667,
#    1190263,
#    1608531,
#    1215124,
#    1182194,
#    1005354],
#   'avg_similarity': 0.04178508620079128},
#  43: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1300803,
#    1186144,
#    1360735,
#    1079318,
#    1245040,
#    1354311,
#    1837970,
#    1640263],
#   'avg_similarity': 0.006101207394167426},
#  44: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1004761,
#    1004847,
#    1898824,
#    1324684,
#    1201081,
#    1219302,
#    1223090,
#    1162955],
#   'avg_similarity': 0.009895723234211267},
#  45: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1221777,
#    1997772,
#    1012989,
#    1266445,
#    1252653,
#    1386625,
#    1393459,
#    1060499],
#   'avg_similarity': 0.02058619418106458},
#  46: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1000067,
#    1196203,
#    1235925,
#    1264364,
#    1647660,
#    1122271,
#    1021893,
#    1100231],
#   'avg_similarity': 0.040635829336877705},
#  47: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1284349,
#    1146933,
#    1003977,
#    1163123,
#    1400386,
#    1019081,
#    1272667,
#    1884814],
#   'avg_similarity': 0.012745752887071523},
#  48: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1005914,
#    1474440,
#    1985825,
#    1112457,
#    1243955,
#    1355667,
#    1189761,
#    1022648],
#   'avg_similarity': 0.033192499232994076},
#  49: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1876255,
#    1139690,
#    1300959,
#    1001940,
#    1916989,
#    1245122,
#    1647874,
#    1195582],
#   'avg_similarity': 0.014933876307366355},
#  50: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1236934,
#    1197255,
#    1034976,
#    1285623,
#    1920071,
#    1270497,
#    1239666,
#    1119141],
#   'avg_similarity': 0.015322833761877536},
#  51: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1194991,
#    1236213,
#    1269304,
#    1228136,
#    1123914,
#    1162201,
#    1393496,
#    1076130],
#   'avg_similarity': 0.00579809761905248},
#  52: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1859448,
#    1280803,
#    1550673,
#    1055003,
#    1225379,
#    1224295,
#    1224612,
#    1582454],
#   'avg_similarity': 0.021995282132132563},
#  53: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1013614,
#    1137580,
#    1144715,
#    1396059,
#    1505103,
#    1260241,
#    1278745,
#    1118096],
#   'avg_similarity': 0.01559899147590577},
#  54: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1284557,
#    1207111,
#    1604011,
#    1903679,
#    1222163,
#    1019835,
#    1170202,
#    1219524],
#   'avg_similarity': 0.02197218245592212},
#  55: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1947000,
#    1409246,
#    1502969,
#    1114543,
#    1075898,
#    1438187,
#    1175691,
#    1185177],
#   'avg_similarity': 0.03264265134511751},
#  56: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1325598,
#    1226481,
#    1004485,
#    1605366,
#    1043509,
#    1107794,
#    1189443,
#    1908574],
#   'avg_similarity': 0.03146774711157324},
#  57: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1764158,
#    1143566,
#    1066882,
#    1255451,
#    1217261,
#    1865286,
#    1113478,
#    1010351],
#   'avg_similarity': 0.05192052230931437},
#  58: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1404105,
#    1295603,
#    1254172,
#    1167635,
#    1361588,
#    1038907,
#    1089025,
#    1014542],
#   'avg_similarity': 0.01816356781173934},
#  59: {'group_size': 8,
#   'group_similarity': 'random',
#   'group_members': [1694373,
#    1006514,
#    1213854,
#    1216155,
#    1865286,
#    1213142,
#    1225785,
#    1218634],
#   'avg_similarity': 0.02755624945987157},
#  60: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1217008, 1194434],
#   'avg_similarity': 0.5495657086451433},
#  61: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1212329, 1207902],
#   'avg_similarity': 0.5064785237781588},
#  62: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1846560, 1604375],
#   'avg_similarity': 0.6307969101664312},
#  63: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1263844, 1165263],
#   'avg_similarity': 0.5886743646682006},
#  64: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1451130, 1039599],
#   'avg_similarity': 0.5017602578580804},
#  65: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1157170, 1129796],
#   'avg_similarity': 0.572658646470196},
#  66: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1078947, 1686051],
#   'avg_similarity': 0.5442281433276315},
#  67: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1181392, 1185705],
#   'avg_similarity': 0.5610464722105756},
#  68: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1055246, 1126696],
#   'avg_similarity': 0.5587778145726023},
#  69: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1255882, 1134441],
#   'avg_similarity': 0.5489974219776101},
#  70: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1387930, 1936578],
#   'avg_similarity': 0.9999999999999996},
#  71: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1213854, 1198871],
#   'avg_similarity': 0.6882044337513404},
#  72: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1180363, 1157714],
#   'avg_similarity': 0.5793539786007447},
#  73: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1356607, 1236738],
#   'avg_similarity': 0.505695521174991},
#  74: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1121498, 1060499],
#   'avg_similarity': 0.5585079662741532},
#  75: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1184762, 1144911],
#   'avg_similarity': 0.5020271784678642},
#  76: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1130804, 1979847],
#   'avg_similarity': 0.9999999999999982},
#  77: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1196681, 1356631],
#   'avg_similarity': 0.9999999999999998},
#  78: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1183876, 1209317],
#   'avg_similarity': 0.9999999999999978},
#  79: {'group_size': 2,
#   'group_similarity': 'similar',
#   'group_members': [1065010, 1775941],
#   'avg_similarity': 0.5212927847893098},
#  80: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1666823, 1430963, 1030557, 2017960],
#   'avg_similarity': 0.9999999999999979},
#  81: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1183143, 1206063, 1912073, 1262657],
#   'avg_similarity': 0.4871804640766431},
#  82: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1240219, 1893257, 1062080, 1193044],
#   'avg_similarity': 0.5680611580318443},
#  83: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1006466, 1389471, 1165895, 1213809],
#   'avg_similarity': 0.448295401630508},
#  84: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1255156, 1006724, 1681975, 1867074],
#   'avg_similarity': 0.9999999999999996},
#  85: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1211855, 1209664, 1103172, 1076345],
#   'avg_similarity': 0.43018359829612857},
#  86: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1010311, 1061532, 1466478, 1832353],
#   'avg_similarity': 0.44898720457025637},
#  87: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1360053, 1224295, 1221399, 1018523],
#   'avg_similarity': 0.4552987768853208},
#  88: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1278745, 1221399, 1224295, 1360053],
#   'avg_similarity': 0.45734225533541445},
#  89: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1265629, 1224855, 1072986, 1226880],
#   'avg_similarity': 0.42942778939754006},
#  90: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1052127, 1144715, 1205159, 1067750],
#   'avg_similarity': 0.4596080830954718},
#  91: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1232581, 1255091, 1120866, 1254398],
#   'avg_similarity': 0.4507626955981332},
#  92: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1365765, 1034827, 1103774, 1054242],
#   'avg_similarity': 0.4893390385604181},
#  93: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1142742, 1002695, 1084123, 1078943],
#   'avg_similarity': 0.5083032759350484},
#  94: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1283660, 1951881, 1141413, 1142409],
#   'avg_similarity': 0.5468665108996392},
#  95: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1284102, 1126410, 1223913, 1059230],
#   'avg_similarity': 0.4717105906798311},
#  96: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1028961, 2032505, 1329637, 1095426],
#   'avg_similarity': 0.9999999999999992},
#  97: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1042239, 1213735, 1204723, 1205921],
#   'avg_similarity': 0.6832714246675974},
#  98: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1099317, 1205921, 1207569, 1084406],
#   'avg_similarity': 0.47845270612461593},
#  99: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1170383, 2042208, 1034827, 1140417],
#   'avg_similarity': 0.3965814850738634},
#  100: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1200315,
#    1208054,
#    1209326,
#    1060499,
#    1215905,
#    1199234,
#    1119676,
#    1844111],
#   'avg_similarity': 0.3592657469808446},
#  101: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1269883,
#    1903608,
#    1055458,
#    1208171,
#    1797823,
#    1008513,
#    1210473,
#    1196804],
#   'avg_similarity': 0.4524573931724297},
#  102: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1177814,
#    1186270,
#    1100667,
#    1406732,
#    1951019,
#    1298860,
#    1256577,
#    1142531],
#   'avg_similarity': 0.33988024826638713},
#  103: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1048496,
#    1065607,
#    1000513,
#    1034534,
#    1037083,
#    1035531,
#    1154133,
#    1173792],
#   'avg_similarity': 0.3897423741107508},
#  104: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1799506,
#    1286865,
#    2024608,
#    1020486,
#    1207521,
#    1059431,
#    1107090,
#    1235741],
#   'avg_similarity': 0.3638402295212146},
#  105: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1122134,
#    1282569,
#    1287978,
#    1287038,
#    1820305,
#    1149294,
#    1397209,
#    1066078],
#   'avg_similarity': 0.3915443222460115},
#  106: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1136602,
#    1495734,
#    1226084,
#    1228140,
#    1208287,
#    1060499,
#    1206064,
#    1666232],
#   'avg_similarity': 0.36124321989323604},
#  107: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1142271,
#    1644588,
#    1104909,
#    1110028,
#    1083893,
#    1207708,
#    1866779,
#    1103065],
#   'avg_similarity': 0.3657359105511321},
#  108: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1287038,
#    1037746,
#    1944469,
#    1078625,
#    1046448,
#    1350145,
#    1227233,
#    1149294],
#   'avg_similarity': 0.5253576248351244},
#  109: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1909490,
#    1324444,
#    1123444,
#    1270325,
#    1451130,
#    1065489,
#    1673185,
#    1665540],
#   'avg_similarity': 0.35109158593264084},
#  110: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1393119,
#    1294080,
#    1340606,
#    1149986,
#    1166271,
#    1216807,
#    1213842,
#    1099317],
#   'avg_similarity': 0.4549517384584173},
#  111: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1410998,
#    1216464,
#    1154133,
#    1119676,
#    1294331,
#    1411687,
#    1202060,
#    1213224],
#   'avg_similarity': 0.3892829448606025},
#  112: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1236738,
#    1356607,
#    1282569,
#    1227953,
#    1066078,
#    1165358,
#    1211171,
#    1019378],
#   'avg_similarity': 0.3743222184252873},
#  113: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1592043,
#    1278001,
#    1021833,
#    1045782,
#    1269791,
#    1619963,
#    1391613,
#    1358604],
#   'avg_similarity': 0.3565810016972332},
#  114: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1179130,
#    1124065,
#    1216268,
#    1214227,
#    1718475,
#    1844111,
#    1118508,
#    1164726],
#   'avg_similarity': 0.43696164503882196},
#  115: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1041633,
#    1049388,
#    1097526,
#    1851305,
#    1290507,
#    1118173,
#    1234923,
#    1158369],
#   'avg_similarity': 0.28505033635258437},
#  116: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1022794,
#    1218536,
#    1167211,
#    1041516,
#    1202060,
#    1203902,
#    1097099,
#    1196804],
#   'avg_similarity': 0.3589971628789589},
#  117: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1216925,
#    1205584,
#    1205085,
#    1089523,
#    1389759,
#    1159930,
#    1191960,
#    1199413],
#   'avg_similarity': 0.38559618351406655},
#  118: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1165896,
#    1253739,
#    1201812,
#    1217196,
#    1196804,
#    1198871,
#    1034838,
#    1208054],
#   'avg_similarity': 0.41958138055700556},
#  119: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1902473,
#    1258142,
#    1356669,
#    1858895,
#    1120912,
#    1038969,
#    1592043,
#    1062080],
#   'avg_similarity': 0.3199440643204509},
#  120: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1001115, 1043126],
#   'avg_similarity': -0.009945766271163985},
#  121: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1393931, 1251932],
#   'avg_similarity': -0.011352129418715117},
#  122: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1359948, 1269564],
#   'avg_similarity': 0.08252156620391708},
#  123: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1262677, 1126696],
#   'avg_similarity': -0.008889416438596656},
#  124: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1304533, 1944444],
#   'avg_similarity': -0.0032384139665864323},
#  125: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1040928, 1224146],
#   'avg_similarity': -0.010548673184849457},
#  126: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1413139, 1120931],
#   'avg_similarity': -0.009139363007010149},
#  127: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1404105, 1004362],
#   'avg_similarity': -0.011014279828883432},
#  128: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1489449, 1098947],
#   'avg_similarity': -0.012201604133235129},
#  129: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1139365, 1511164],
#   'avg_similarity': -0.01052011232817739},
#  130: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1322183, 1265895],
#   'avg_similarity': -0.013575670046005631},
#  131: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1235408, 1181392],
#   'avg_similarity': -0.010045949447852424},
#  132: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1107874, 1230191],
#   'avg_similarity': -0.011100394654765608},
#  133: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1266755, 1210217],
#   'avg_similarity': -0.006409854953537903},
#  134: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1152390, 1100074],
#   'avg_similarity': 0.05844201961927088},
#  135: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1223473, 1040098],
#   'avg_similarity': -0.011120518188614436},
#  136: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1071118, 1044048],
#   'avg_similarity': -0.007575216366245875},
#  137: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1205533, 1041042],
#   'avg_similarity': -0.005000714589189051},
#  138: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1226760, 1950031],
#   'avg_similarity': 0.07855541490734859},
#  139: {'group_size': 2,
#   'group_similarity': 'divergent',
#   'group_members': [1324444, 1003712],
#   'avg_similarity': -0.012376726473359276},
#  140: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1192021, 1253065, 1246161, 1394317],
#   'avg_similarity': 0.01249299870931768},
#  141: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1129789, 1188744, 1840307, 1399242],
#   'avg_similarity': 0.03892139963649092},
#  142: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1049843, 1043141, 1141920, 1083794],
#   'avg_similarity': 0.009249260657161725},
#  143: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1281621, 1469764, 1649493, 1104491],
#   'avg_similarity': 0.04214424873819753},
#  144: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1212059, 1387436, 1044421, 1000582],
#   'avg_similarity': -0.00956750450615102},
#  145: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1218634, 1281588, 1387930, 1218194],
#   'avg_similarity': 0.02243111931812501},
#  146: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1537657, 1763922, 1820305, 1708783],
#   'avg_similarity': 0.015845689886967423},
#  147: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1093422, 1059736, 1509439, 1274530],
#   'avg_similarity': -0.004386821712668994},
#  148: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1154996, 1213524, 1198558, 1222691],
#   'avg_similarity': 0.035001537593005144},
#  149: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1249047, 1164133, 1268161, 2012543],
#   'avg_similarity': -0.006660060750825124},
#  150: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1120794, 1254398, 1216671, 1186038],
#   'avg_similarity': 0.02560342287496664},
#  151: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1178254, 1300715, 1274444, 1229652],
#   'avg_similarity': 0.02046220430791296},
#  152: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1064848, 1169832, 1222895, 1125303],
#   'avg_similarity': -0.007059367406147959},
#  153: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1055122, 1049428, 1137655, 1253065],
#   'avg_similarity': 0.061346620035632245},
#  154: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1006666, 1165937, 1456577, 1221534],
#   'avg_similarity': 0.017317937011723905},
#  155: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1304533, 1218536, 1035531, 1219324],
#   'avg_similarity': -0.009061055458282905},
#  156: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1979847, 1166139, 1094363, 1166064],
#   'avg_similarity': 0.02873327772460565},
#  157: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1189581, 1223159, 1278825, 1279089],
#   'avg_similarity': 0.09766448542803811},
#  158: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1026306, 1204097, 1320442, 1115688],
#   'avg_similarity': 0.030063557560856904},
#  159: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1088889, 1362729, 1059725, 1222163],
#   'avg_similarity': -0.011540895787097704},
#  160: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1174718,
#    1007198,
#    1290767,
#    1175938,
#    1269552,
#    1515329,
#    1214762,
#    1280793],
#   'avg_similarity': 0.04612272700700461},
#  161: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1255093,
#    1266755,
#    1027693,
#    1980435,
#    1266408,
#    1333557,
#    1005560,
#    1434293],
#   'avg_similarity': 0.01038434086491899},
#  162: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1203928,
#    1308156,
#    1467023,
#    1283309,
#    1934191,
#    1136745,
#    1358785,
#    1190006],
#   'avg_similarity': 0.032153701194626995},
#  163: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1230191,
#    1112534,
#    1243721,
#    1284349,
#    1026697,
#    1230289,
#    1392955,
#    1970500],
#   'avg_similarity': 0.038935133848005586},
#  164: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1098103,
#    1075700,
#    1134778,
#    1215124,
#    1041030,
#    1222664,
#    1147122,
#    1207423],
#   'avg_similarity': 0.05311621452634796},
#  165: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1006408,
#    1357341,
#    1004849,
#    1164188,
#    1378501,
#    1354417,
#    1259750,
#    1292374],
#   'avg_similarity': 0.033155742561394995},
#  166: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1185024,
#    1220947,
#    1166946,
#    1283446,
#    1255667,
#    1177413,
#    1143424,
#    1201051],
#   'avg_similarity': 0.01837050860785636},
#  167: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1274690,
#    1059785,
#    1361080,
#    1165047,
#    1117674,
#    1000036,
#    1219577,
#    1404675],
#   'avg_similarity': 0.04041785400648528},
#  168: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1842106,
#    1165070,
#    2056340,
#    1762859,
#    1144708,
#    1082551,
#    1151047,
#    1364900],
#   'avg_similarity': 0.00794283416674808},
#  169: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1253724,
#    1093422,
#    1240482,
#    1048332,
#    1753301,
#    1000300,
#    1745643,
#    1211252],
#   'avg_similarity': 0.02786891027049864},
#  170: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1664142,
#    1035728,
#    1236079,
#    1270683,
#    1272667,
#    1249161,
#    1220739,
#    1240552],
#   'avg_similarity': 0.024868324653908844},
#  171: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1014359,
#    1131509,
#    1003957,
#    1265381,
#    1220980,
#    1976379,
#    2025745,
#    1171295],
#   'avg_similarity': 0.02800183344316237},
#  172: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1083598,
#    1008267,
#    1277139,
#    1207521,
#    1253019,
#    1213518,
#    1054242,
#    1077939],
#   'avg_similarity': 0.03734567877093675},
#  173: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1284149,
#    1059095,
#    1398559,
#    1197373,
#    1300715,
#    1000586,
#    2058533,
#    1913676],
#   'avg_similarity': 0.00708238870903371},
#  174: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1215762,
#    1064790,
#    1972850,
#    1320442,
#    1363431,
#    1161251,
#    1100203,
#    1196642],
#   'avg_similarity': 0.004738463992784247},
#  175: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1271502,
#    1258142,
#    1248297,
#    1387930,
#    1387702,
#    1708704,
#    1076288,
#    1130140],
#   'avg_similarity': 0.013250335801847356},
#  176: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1038969,
#    1189783,
#    1270653,
#    1004867,
#    1199402,
#    1119295,
#    1222691,
#    1289617],
#   'avg_similarity': 0.012561746441363878},
#  177: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1114191,
#    1219577,
#    1218911,
#    1132373,
#    1835557,
#    1232459,
#    1230106,
#    1112534],
#   'avg_similarity': 0.0494520409158779},
#  178: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1396561,
#    1358604,
#    1282368,
#    1223590,
#    1150753,
#    1241306,
#    1287176,
#    1037217],
#   'avg_similarity': 0.06870380035117515},
#  179: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1372222,
#    1160009,
#    1151162,
#    1000197,
#    1592605,
#    1660622,
#    1026290,
#    1450430],
#   'avg_similarity': 0.05168456265557577},
#  180: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1034368, 1222877],
#   'avg_similarity': -0.012044320035513277},
#  181: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1429762, 1965776],
#   'avg_similarity': -0.005406043720596194},
#  182: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1244965, 1392126],
#   'avg_similarity': -0.008695172561298212},
#  183: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1151814, 1254482],
#   'avg_similarity': -0.009454727749274515},
#  184: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1036201, 1398559],
#   'avg_similarity': -0.0032231858171253847},
#  185: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1210613, 1191221],
#   'avg_similarity': -0.0111511761216802},
#  186: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1219072, 1335034],
#   'avg_similarity': -0.011080824145585404},
#  187: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1114047, 1251633],
#   'avg_similarity': -0.010245376889483203},
#  188: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1139787, 1060016],
#   'avg_similarity': -0.008504471297939119},
#  189: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1183569, 1121498],
#   'avg_similarity': -0.008495347952809111},
#  190: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1787810, 1416040],
#   'avg_similarity': -0.009252616341808104},
#  191: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1131099, 1121001],
#   'avg_similarity': -0.008846377764971033},
#  192: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1019075, 1272771],
#   'avg_similarity': 0.0962629660455075},
#  193: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1000232, 1217270],
#   'avg_similarity': 0.04059121267450767},
#  194: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1329637, 1626693],
#   'avg_similarity': -0.003624716509027028},
#  195: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1408900, 1734387],
#   'avg_similarity': -0.010508849421954835},
#  196: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1253011, 1893593],
#   'avg_similarity': -0.010848474305018875},
#  197: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1094363, 1653207],
#   'avg_similarity': -0.010156743434841095},
#  198: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1149098, 1123719],
#   'avg_similarity': 0.09561244246137744},
#  199: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1213476, 1012457],
#   'avg_similarity': 0.0580854900781992},
#  200: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1893593, 1154133, 1037083, 1002512],
#   'avg_similarity': 0.20900099442295442},
#  201: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1207793, 1084397, 1041042, 1001115],
#   'avg_similarity': 0.2561425844849744},
#  202: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1173699, 1340606, 1185360, 1703926],
#   'avg_similarity': 0.2623289748827677},
#  203: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1001006, 1252744, 1645346, 1206310],
#   'avg_similarity': 0.21135387022703686},
#  204: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2049904, 1231285, 1037746, 1162954],
#   'avg_similarity': 0.2537360973829762},
#  205: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1201456, 1165895, 1389471, 1254857],
#   'avg_similarity': 0.25447545846234204},
#  206: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1435074, 1034425, 1341570, 1008899],
#   'avg_similarity': 0.2666172953817068},
#  207: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1251932, 1177660, 1075757, 1354019],
#   'avg_similarity': 0.2776906963000551},
#  208: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1366008, 1037083, 1121081, 1262028],
#   'avg_similarity': 0.22406091967034633},
#  209: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1907099, 1213731, 1494147, 1389297],
#   'avg_similarity': 0.49832418268409207},
#  210: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1737753, 1213919, 1119676, 1203304],
#   'avg_similarity': 0.34456255258056956},
#  211: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1820577, 1359948, 1282644, 1001045],
#   'avg_similarity': 0.2235493338895366},
#  212: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1665540, 1010311, 1673185, 1239680],
#   'avg_similarity': 0.25210606520074247},
#  213: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1689187, 1123444, 1103929, 1986488],
#   'avg_similarity': 0.2884706066879844},
#  214: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1168394, 1410597, 1218072, 1087977],
#   'avg_similarity': 0.24352006493233927},
#  215: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1925634, 2015016, 1400386, 1301428],
#   'avg_similarity': 0.4005035987310677},
#  216: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1203304, 1912073, 1065008, 1357701],
#   'avg_similarity': 0.22604464919360712},
#  217: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1211855, 1144715, 1099317, 1055788],
#   'avg_similarity': 0.23409212443842156},
#  218: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1286607, 1303176, 1271502, 1233025],
#   'avg_similarity': 0.24384831422190134},
#  219: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1398559, 1071163, 1674727, 1367431],
#   'avg_similarity': 0.4982289686843669},
#  220: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1820577,
#    1359948,
#    1282644,
#    1031118,
#    1858010,
#    1354808,
#    2056944,
#    1226233],
#   'avg_similarity': 0.3115535213580456},
#  221: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1124387,
#    1944469,
#    1287038,
#    1207793,
#    1142409,
#    1039270,
#    1090492,
#    1401853],
#   'avg_similarity': 0.30365372190292056},
#  222: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1120866,
#    1254398,
#    1278001,
#    1021833,
#    1055602,
#    1099488,
#    1155158,
#    1224829],
#   'avg_similarity': 0.3124236445939243},
#  223: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1243410,
#    1186270,
#    1086949,
#    1127231,
#    1100667,
#    1177814,
#    1665540,
#    1173690],
#   'avg_similarity': 0.34869762483064665},
#  224: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1076120,
#    1210920,
#    1209326,
#    1294331,
#    1084761,
#    1173835,
#    1208702,
#    1179213],
#   'avg_similarity': 0.3550644496936436},
#  225: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1105176,
#    1223348,
#    1278805,
#    1290188,
#    1944469,
#    1104909,
#    1064941,
#    1412277],
#   'avg_similarity': 0.3114614981762193},
#  226: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1011730,
#    1179336,
#    2056705,
#    1002695,
#    1152054,
#    1218536,
#    1191960,
#    1169193],
#   'avg_similarity': 0.3583091969632572},
#  227: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1930194,
#    1036414,
#    1055122,
#    1191914,
#    1035442,
#    1207521,
#    1059431,
#    1005491],
#   'avg_similarity': 0.3526427750389286},
#  228: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1055444,
#    1239656,
#    1057231,
#    1156175,
#    1124490,
#    1118421,
#    1190629,
#    1000705],
#   'avg_similarity': 0.3271118568216634},
#  229: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1103272,
#    1084761,
#    1797823,
#    1708704,
#    1445937,
#    1193904,
#    1199234,
#    1665162],
#   'avg_similarity': 0.28659368002834135},
#  230: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1137583,
#    1205533,
#    1191624,
#    1258453,
#    1089025,
#    1197456,
#    1021207,
#    1109224],
#   'avg_similarity': 0.3304095829077127},
#  231: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1215717,
#    1211375,
#    1076431,
#    1213725,
#    1210675,
#    1164014,
#    1173699,
#    1147215],
#   'avg_similarity': 0.33341440014717516},
#  232: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1129715,
#    1213842,
#    1294080,
#    1210483,
#    1216699,
#    1797823,
#    1491651,
#    1055248],
#   'avg_similarity': 0.3189072875324633},
#  233: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1223913,
#    1357341,
#    1126410,
#    1269590,
#    1078625,
#    1060400,
#    1141413,
#    1489293],
#   'avg_similarity': 0.3100433208765274},
#  234: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1134614,
#    1775941,
#    1201081,
#    1230434,
#    1055055,
#    1019419,
#    1218027,
#    1089144],
#   'avg_similarity': 0.2827294455559735},
#  235: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1000197,
#    1930194,
#    1055122,
#    1036414,
#    1186270,
#    1142531,
#    1951019,
#    1909914],
#   'avg_similarity': 0.2841525100887078},
#  236: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1041516,
#    1410998,
#    2056705,
#    1116649,
#    1202471,
#    1173699,
#    1262657,
#    1222432],
#   'avg_similarity': 0.3072794404619043},
#  237: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1225885,
#    1291971,
#    1970683,
#    1215574,
#    1199595,
#    1167211,
#    1204175,
#    1814929],
#   'avg_similarity': 0.3225011146292239},
#  238: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1269791,
#    2004485,
#    1071205,
#    1698639,
#    1281152,
#    1277107,
#    1396821,
#    1002560],
#   'avg_similarity': 0.31493306673176724},
#  239: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1099585,
#    1526469,
#    1055318,
#    1406748,
#    1355947,
#    1254492,
#    1210613,
#    1902938],
#   'avg_similarity': 0.25707311881173295}}

# %%
# simple similarity viewer per group
np.set_printoptions(precision=4, suppress=True)
idx = 200
member_index = [user_id_indexes.tolist().index(member) for member in group_dict[idx]["group_members"]]
s = sim_matrix[member_index]
s[:,member_index]
# Out:
# array([[ 1.    ,  0.5075,  0.2472, -0.0099],
#        [ 0.5075,  1.    ,  0.5239, -0.0098],
#        [ 0.2472,  0.5239,  1.    , -0.0049],
#        [-0.0099, -0.0098, -0.0049,  1.    ]])

# %%
import pickle
pickle.dump(group_dict, open(preprocessed_dataset_folder+"/group_composition.pkl", "wb"))

# %%
group_similarity = "similar"
group_size = 8
histogram_list = []
for gid in group_dict.keys():
    g = group_dict[gid]
    if g["group_similarity"] == group_similarity and g["group_size"] == group_size:
        member_index = [user_id_indexes.tolist().index(member) for member in g["group_members"]]
        s = sim_matrix[member_index]
        histogram_list.extend(s[:,member_index].flatten().tolist())

        
plt.hist(histogram_list)
#plt.yscale("log")
plt.xlabel("PCC for "+group_similarity+" groups, size:"+str(group_size)+" threshold:"+str(cfg.similar_threshold))    
plt.savefig("pcc_"+group_similarity+"_"+str(group_size)+"_"+str(int(cfg.similar_threshold*10))+".png", dpi=300)

# %%
group_similarity = "divergent"
group_size = 8
histogram_list = []
for gid in group_dict.keys():
    g = group_dict[gid]
    if g["group_similarity"] == group_similarity and g["group_size"] == group_size:
        member_index = [user_id_indexes.tolist().index(member) for member in g["group_members"]]
        s = sim_matrix[member_index]
        histogram_list.extend(s[:,member_index].flatten().tolist())

        
plt.hist(histogram_list)
#plt.yscale("log")
plt.xlabel("PCC for "+group_similarity+" groups, size:"+str(group_size)+" threshold:"+str(cfg.dissimilar_threshold))    
plt.savefig("pcc_"+group_similarity+"_"+str(group_size)+"_"+str(int(cfg.dissimilar_threshold*10))+".png", dpi=300)

# %%
groups_list = list()
for group in group_dict:
    groups_list.append(
        {
            'group_id': group,
            'group_size': group_dict[group]['group_size'],
            'group_similarity': group_dict[group]['group_similarity'],
            'group_members': group_dict[group]['group_members'],
            'avg_similarity': group_dict[group]['avg_similarity']
        }
    )

groups_df = pd.DataFrame.from_records(groups_list)
display(groups_df.head(10))
# Out:
#    group_id  group_size group_similarity group_members  avg_similarity
# 0         0           2           random  [4805, 5428]        0.095566
# 1         1           2           random   [5251, 146]        0.136992
# 2         2           2           random  [3916, 4539]        0.046719
# 3         3           2           random  [2059, 5558]        0.066448
# 4         4           2           random   [1789, 463]        0.162919
# 5         5           2           random  [3234, 4068]       -0.008439
# 6         6           2           random  [5216, 4855]        0.089651
# 7         7           2           random   [339, 5736]        0.067340
# 8         8           2           random   [153, 4515]       -0.010605
# 9         9           2           random  [3450, 2157]        0.116474

# %% [markdown]
# ### Comparing groups internal average similarity between the different types and sizes

# %%
import seaborn as sns


plt.rcParams["figure.figsize"] = (20,10)
sns.boxplot(x = groups_df['group_size'],
            y = groups_df['avg_similarity'],
            hue = groups_df['group_similarity'])
import matplotlib.pyplot as plt

# %%
groups_df.to_csv(preprocessed_dataset_folder+"/group_composition.csv")
