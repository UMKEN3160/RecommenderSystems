# %%
# all imports up here, rerun this block when adding
import pandas as pd
import numpy as np
import cv2 as cv

# %%
#assumes dataset in folder
wines   = pd.read_csv("XWines_Full_100K_wines.csv", low_memory=False, encoding="utf-8", memory_map=True)
# ratings = pd.read_csv("XWines_Full_21M_ratings.csv", low_memory=False, encoding="utf-8", memory_map=True)
len(wines), #len(ratings)

# print(ratings)
print(wines)
# Out:
#         WineID                           WineName       Type  \
# 0       100001                 Espumante Moscatel  Sparkling
# 1       100002                         Ancellotta        Red
# 2       100003                 Cabernet Sauvignon        Red
# 3       100004                     Virtus Moscato      White
# 4       100005    Maison de Ville Cabernet-Merlot        Red
# ...        ...                                ...        ...
# 100641  200791      Rulandské Šedé Výběr z Hroznů      White
# 100642  200792  Top Collection Merlot Pozdní Sběr    Dessert
# 100643  200793      Falter Ego Gelber Muskateller      White
# 100644  200794                  Reisberg Riesling      White
# 100645  200795                          Rotleiten        Red
#
#                             Elaborate  \
# 0                       Varietal/100%
# 1                       Varietal/100%
# 2                       Varietal/100%
# 3                       Varietal/100%
# 4       Assemblage/Bordeaux Red Blend
# ...                               ...
# 100641                  Varietal/100%
# 100642                  Varietal/100%
# 100643                  Varietal/100%
# 100644                  Varietal/100%
# 100645               Assemblage/Blend
#
#                                                    Grapes  \
# 0                                      ['Muscat/Moscato']
# 1                                          ['Ancellotta']
# 2                                  ['Cabernet Sauvignon']
# 3                                      ['Muscat/Moscato']
# 4                        ['Cabernet Sauvignon', 'Merlot']
# ...                                                   ...
# 100641                                     ['Pinot Gris']
# 100642                                         ['Merlot']
# 100643                             ['Gelber Muskateller']
# 100644                                       ['Riesling']
# 100645  ['Cabernet Sauvignon', 'Zweigelt', 'St. Laurent']
#
#                                                 Harmonize   ABV  \
# 0                      ['Pork', 'Rich Fish', 'Shellfish']   7.5
# 1       ['Beef', 'Barbecue', 'Codfish', 'Pasta', 'Pizz...  12.0
# 2                             ['Beef', 'Lamb', 'Poultry']  12.0
# 3                                       ['Sweet Dessert']  12.0
# 4                ['Beef', 'Lamb', 'Game Meat', 'Poultry']  11.0
# ...                                                   ...   ...
# 100641  ['Rich Fish', 'Shellfish', 'Maturated Cheese',...  13.0
# 100642                              ['Beef', 'Game Meat']  13.5
# 100643                    ['Spicy Food', 'Sweet Dessert']  12.5
# 100644  ['Pork', 'Shellfish', 'Spicy Food', 'Poultry',...  12.5
# 100645  ['Beef', 'Lamb', 'Pork', 'Spicy Food', 'Matura...  13.5
#
#                  Body Acidity Code         Country  RegionID     RegionName  \
# 0       Medium-bodied    High   BR          Brazil      1001   Serra Gaúcha
# 1       Medium-bodied  Medium   BR          Brazil      1001   Serra Gaúcha
# 2         Full-bodied    High   BR          Brazil      1001   Serra Gaúcha
# 3       Medium-bodied  Medium   BR          Brazil      1001   Serra Gaúcha
# 4         Full-bodied  Medium   BR          Brazil      1001   Serra Gaúcha
# ...               ...     ...  ...             ...       ...            ...
# 100641  Medium-bodied  Medium   CZ  Czech Republic      2295         Morava
# 100642  Medium-bodied    High   CZ  Czech Republic      2295         Morava
# 100643  Medium-bodied    High   AT         Austria      2086  Südsteiermark
# 100644  Medium-bodied    High   AT         Austria      2093           Wien
# 100645  Medium-bodied    High   AT         Austria      2093           Wien
#
#         WineryID                      WineryName  \
# 0          10001                     Casa Perini
# 1          10001                     Casa Perini
# 2          10002                    Castellamare
# 3          10003                  Monte Paschoal
# 4          10000                          Aurora
# ...          ...                             ...
# 100641     67056  Rodinné Vinařství Pavel Binder
# 100642     66978              Vinarstvi Mutěnice
# 100643     62547                  Hannes Sabathi
# 100644     62795                           Zahel
# 100645     62795                           Zahel
#
#                                        Website  \
# 0             http://www.vinicolaperini.com.br
# 1             http://www.vinicolaperini.com.br
# 2       https://www.emporiocastellamare.com.br
# 3              http://www.montepaschoal.com.br
# 4             http://www.vinicolaaurora.com.br
# ...                                        ...
# 100641               http://www.pavelbinder.cz
# 100642         http://www.vinarstvimutenice.cz
# 100643             http://www.sabathi-weine.at
# 100644                     http://www.zahel.at
# 100645                     http://www.zahel.at
#
#                                                  Vintages
# 0       [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 1       [2016, 2015, 2014, 2013, 2012, 2011, 2010, 200...
# 2       [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 3       [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 4       [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# ...                                                   ...
# 100641  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...
# 100642   [2020, 2019, 2018, 2017, 2016, 2015, 2013, 2010]
# 100643  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 100644  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 100645  [2020, 2019, 2017, 2015, 2014, 2013, 2012, 201...
#
# [100646 rows x 17 columns]

# %%
def read():
    ##assumes dataset in folder
    wines   = pd.read_csv("XWines_Full_100K_wines.csv", low_memory=False, encoding="utf-8", memory_map=True)
    ratings = pd.read_csv("XWines_Full_21M_ratings.csv", low_memory=False, encoding="utf-8", memory_map=True)
    return wines,ratings

# %%
# Step 2: Get user input
wine_type = input("Enter the type of wine (e.g., red, white, rosé, sparkling): ").lower()
wine_country = input("Enter the country of the wine (e.g., Brazil, New Zealand): ").lower()
wine_body = input("Enter the body of the wine(e.g. ligth-bodied, medium-bodied, full-bodied): ").lower()

# Step 3: Check if there are matches for both preferences
filtered_wines = wines.copy()

filtered_wines = wines[(wines['Type'].str.lower() == wine_type) 
                       & (wines['Country'].str.lower() == wine_country)
                       & (wines['Body'].str.lower() == wine_body)]

if filtered_wines.empty:
    filtered_wines = wines[(wines['Type'].str.lower() == wine_type)
                           & (wines['Country'].str.lower() == wine_country)]
    if not filtered_wines.empty:
        # Step 5: Notify the user that the region was left out
        print(f"No '{wine_type}' wines in country '{wine_country}' found with body '{wine_body}'")
        print(f"Showing all '{wine_type}' wines from country '{wine_country}' instead.")
    else:
        filtered_wines = wines[wines['Type'].str.lower() == wine_type]
        if not filtered_wines.empty:
            print(f"No '{wine_type}' wines in country '{wine_country}'. Showing all '{wine_type}'instead")
        else:
            # No wines matching even the type
            print(f"No wines found for the type '{wine_type}'.")
else:
    # Found wines for both type and region
    print(f"Showing '{wine_type}' wines from '{wine_country}'.")

# Step 6: Display the result
if not filtered_wines.empty:
    print(filtered_wines)
else:
    print("No wines found that match your preferences.")
# Out:
# No 'white' wines in country 'brazil' found with body 'bodied'
# Showing all 'white' wines from country 'brazil' instead.
#        WineID                                           WineName   Type  \
# 3      100004                                     Virtus Moscato  White
# 40     100041                                 Dádivas Chardonnay  White
# 42     100043                         Leopoldina Gran Chardonnay  White
# 74     100075                  Identidade Terroir Gewürztraminer  White
# 85     100086                        Selecão Chardonnay-Viognier  White
# ...       ...                                                ...    ...
# 6045   106047  Vinho Branco Seco Alto Feliz Rs Brasil Moscato...  White
# 10354  110360                                 Dádivas Chardonnay  White
# 33614  133636        Riesling Renano Vinho Fino Branco Mero Seco  White
# 67288  167393                             Di Mallo Moscato Suave  White
# 91823  191946     Bituruna Vinho Branco Seco Fino Moscato Giallo  White
#
#               Elaborate                      Grapes  \
# 3         Varietal/100%          ['Muscat/Moscato']
# 40        Varietal/100%              ['Chardonnay']
# 42        Varietal/100%              ['Chardonnay']
# 74        Varietal/100%          ['Gewürztraminer']
# 85     Assemblage/Blend  ['Chardonnay', 'Viognier']
# ...                 ...                         ...
# 6045      Varietal/100%   ['Muscat/Moscato Giallo']
# 10354     Varietal/100%              ['Chardonnay']
# 33614     Varietal/100%                ['Riesling']
# 67288     Varietal/100%          ['Muscat/Moscato']
# 91823     Varietal/100%   ['Muscat/Moscato Giallo']
#
#                                                Harmonize   ABV           Body  \
# 3                                      ['Sweet Dessert']  12.0  Medium-bodied
# 40        ['Pork', 'Rich Fish', 'Vegetarian', 'Poultry']  13.5    Full-bodied
# 42        ['Pork', 'Rich Fish', 'Vegetarian', 'Poultry']  13.5    Full-bodied
# 74     ['Rich Fish', 'Spicy Food', 'Sweet Dessert', '...  12.5  Medium-bodied
# 85        ['Pork', 'Rich Fish', 'Vegetarian', 'Poultry']  12.0  Medium-bodied
# ...                                                  ...   ...            ...
# 6045         ['Pasta', 'Pork', 'Shellfish', 'Lean Fish']  13.0  Medium-bodied
# 10354     ['Pork', 'Rich Fish', 'Vegetarian', 'Poultry']  14.0    Full-bodied
# 33614  ['Pork', 'Rich Fish', 'Spicy Food', 'Sweet Des...  12.0  Medium-bodied
# 67288                                  ['Sweet Dessert']  11.5  Medium-bodied
# 91823  ['Pasta', 'Shellfish', 'Maturated Cheese', 'Ha...  12.0  Medium-bodied
#
#       Acidity Code Country  RegionID         RegionName  WineryID  \
# 3      Medium   BR  Brazil      1001       Serra Gaúcha     10003
# 40       High   BR  Brazil      1002  Vale dos Vinhedos     10020
# 42       High   BR  Brazil      1001       Serra Gaúcha     10014
# 74     Medium   BR  Brazil      1001       Serra Gaúcha     10014
# 85     Medium   BR  Brazil      1004    Campanha Gaúcha     10013
# ...       ...  ...     ...       ...                ...       ...
# 6045     High   BR  Brazil      1001       Serra Gaúcha     10022
# 10354  Medium   BR  Brazil      1002  Vale dos Vinhedos     10020
# 33614    High   BR  Brazil      1001       Serra Gaúcha     27620
# 67288    High   BR  Brazil      1001       Serra Gaúcha     10026
# 91823    High   BR  Brazil      1015             Paraná     53200
#
#            WineryName                                     Website  \
# 3      Monte Paschoal             http://www.montepaschoal.com.br
# 40      Lidio Carraro                 http://www.lidiocarraro.com
# 42       Casa Valduga               http://www.casavalduga.com.br
# 74       Casa Valduga               http://www.casavalduga.com.br
# 85              Miolo                     http://www.miolo.com.br
# ...               ...                                         ...
# 6045      Don Guerino                http://www.donguerino.com.br
# 10354   Lidio Carraro                 http://www.lidiocarraro.com
# 33614      Weingierle  http://www.vinicolaalema-weinzierle.com.br
# 67288        Panizzon                  http://www.panizzon.com.br
# 91823        Di Sandi                      https://disandi.com.br
#
#                                                 Vintages
# 3      [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 40     [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 42     [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 74     [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 85     [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# ...                                                  ...
# 6045   [2018, 2017, 2016, 2015, 2014, 2013, 2012, 201...
# 10354  [2017, 2016, 2015, 2014, 2013, 2012, 2011, 201...
# 33614               [2017, 2016, 2014, 2012, 2011, 2010]
# 67288  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 91823  [2021, 2020, 2019, 2018, 2016, 2014, 2012, 201...
#
# [191 rows x 17 columns]
